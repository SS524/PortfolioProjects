# %% [markdown]
# ## Importing Necessary Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Part 1: Data Reading

# %% [markdown]
# ## Reading .CSV data from local machine

# %%
df=pd.read_csv("E:\\Excel Practice\\adult.csv")

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# ## Making a copy of original dataframe

# %%
df_copy=df.copy()

# %%
df_copy.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# ## Checking dataframe information

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# # Part 2: Data Cleaning

# %% [markdown]
# ## Trying to find out duplicated values

# %%
df_copy[df_copy.duplicated()]
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22300   25            Private  195994        1st-4th              2
# ...

# %% [markdown]
# ## Removing duplicate values

# %%
df_copy=df_copy.drop_duplicates(keep="first")

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education-num   32537 non-null  int64
#  5   marital-status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    32537 non-null  object
#  8   race            32537 non-null  object
#  9   sex             32537 non-null  object
#  10  capital-gain    32537 non-null  int64
#  11  capital-loss    32537 non-null  int64
#  12  hours-per-week  32537 non-null  int64
#  13  native-country  32537 non-null  object
#  14  income          32537 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB

# %% [markdown]
# ## Extracting all the column names from the dataframe

# %%
columns=list(df_copy.columns)

# %%
columns
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'income']

# %% [markdown]
# ## Finding out unique values for all the columns

# %%
for col in columns:
    print(f"Unique values for column '{col}'")
    print(df_copy[col].unique())
    print("==============================================")
# Out:
# Unique values for column 'age'
# [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
# ...
# Unique values for column 'workclass'
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# ...
# Unique values for column 'fnlwgt'
# [ 77516  83311 215646 ...  34066  84661 257302]
# ...
# Unique values for column 'education'
# [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# ...
# Unique values for column 'education-num'
# [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
# ...
# Unique values for column 'marital-status'
# [' Never-married' ' Married-civ-spouse' ' Divorced'
# ...

# %% [markdown]
# ## Seperating non-numeric-features from the column names

# %%
non_numeric_features=[non_num for non_num in df_copy.columns if df_copy[non_num].dtype=='O']

# %%
non_numeric_features
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country',
#  'income']

# %% [markdown]
# ## As there are white spaces present for all the non-numeric values, we are performing strip() operation to remove the unnecessary spaces

# %%
for feature in non_numeric_features:
    df_copy[feature]=df_copy[feature].apply(lambda x: x.strip())

# %%
for col in non_numeric_features:
    print(f"Unique values for column '{col}' after removing spaces")
    print(df_copy[col].unique())
    print("==============================================")
# Out:
# Unique values for column 'workclass' after removing spaces
# ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
# ...
# Unique values for column 'education' after removing spaces
# ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
# ...
# Unique values for column 'marital-status' after removing spaces
# ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
# ...
# Unique values for column 'occupation' after removing spaces
# ['Adm-clerical' 'Exec-managerial' 'Handlers-cleaners' 'Prof-specialty'
#  'Other-service' 'Sales' 'Craft-repair' 'Transport-moving'
#  'Farming-fishing' 'Machine-op-inspct' 'Tech-support' '?'
#  'Protective-serv' 'Armed-Forces' 'Priv-house-serv']
# ...
# Unique values for column 'relationship' after removing spaces
# ...

# %% [markdown]
# ## For 'native-country' column, we have some incorrect values. We are trying to identify and drop those figures

# %%
df_copy[(df_copy['native-country']=='?')|(df_copy['native-country']=='South')]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 14      40           Private  121772     Assoc-voc             11
# 27      54                 ?  180211  Some-college             10
# 38      31           Private   84154  Some-college             10
# 51      18           Private  226956       HS-grad              9
# 61      32                 ?  293936       7th-8th              4
# ...    ...               ...     ...           ...            ...
# 32449   44      Self-emp-inc   71556       Masters             14
# 32469   58      Self-emp-inc  181974     Doctorate             16
# 32492   42  Self-emp-not-inc  217597       HS-grad              9
# 32510   39           Private  107302       HS-grad              9
# 32525   81                 ?  120478     Assoc-voc             11
#
#               marital-status      occupation   relationship  \
# 14        Married-civ-spouse    Craft-repair        Husband
# ...

# %%
df_copy=df_copy[~((df_copy['native-country']=='?')|(df_copy['native-country']=='South'))]

# %%
df_copy
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# ## For 'workclass' and 'occupation' columns, we have some incorrect values. Trying to identify and drop those records

# %%
df_copy[(df_copy['workclass']=='?')|(df_copy['occupation']=='?')]
# Out:
#        age workclass  fnlwgt     education  education-num      marital-status  \
# 69      25         ?  200681  Some-college             10       Never-married
# 77      67         ?  212759          10th              6  Married-civ-spouse
# 106     17         ?  304873          10th              6       Never-married
# 128     35         ?  129305       HS-grad              9  Married-civ-spouse
# 149     43         ?  174662  Some-college             10            Divorced
# ...    ...       ...     ...           ...            ...                 ...
# 32530   35         ?  320084     Bachelors             13  Married-civ-spouse
# 32531   30         ?   33811     Bachelors             13       Never-married
# 32539   71         ?  287372     Doctorate             16  Married-civ-spouse
# 32541   41         ?  202822       HS-grad              9           Separated
# 32542   72         ?  129912       HS-grad              9  Married-civ-spouse
#
# ...

# %%
df_copy=df_copy[~((df_copy['workclass']=='?')|(df_copy['occupation']=='?'))]

# %%
df_copy
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# ## Trying to find out the distribution of 'fnlwgt' column

# %%
plt.figure(figsize=(13,13))
sns.histplot(df_copy['fnlwgt'],kde=True)
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='Count'>

# %% [markdown]
# ### From the above diagram, we understood that the distribution is following a Right Skewed distribution. Let's try to find out the outliers and remove those points from our dataframe

# %%
def identify_outliers(dataframe,columnName):
    sorted_list=list(dataframe[columnName].sort_values(ascending=False))
    res=[]
    q1=np.percentile(sorted_list,25)
    q3=np.percentile(sorted_list,75)
    IQR=q3-q1
    lower_bound=q1-(1.5*IQR)
    upper_bound=q3+(1.5*IQR)
    for i in sorted_list:
        if(i>upper_bound or i<lower_bound):
            res.append(i)
    return res

# %%
len(identify_outliers(df_copy,'fnlwgt'))
# Out:
# 903

# %% [markdown]
# ## There are total 903 outliers for 'fnlwgt' column. Let's remove it

# %%
for i in identify_outliers(df_copy,'fnlwgt'):
    df_copy=df_copy[~(df_copy['fnlwgt']==i)]

# %%
df_copy
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
plt.figure(figsize=(13,13))
sns.histplot(df_copy['fnlwgt'],kde=True)
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='Count'>

# %% [markdown]
# ### From the abouve diagram, we can see that the distribution has shifted towards the centre of the graph after removing the outliers

# %% [markdown]
# ## Let's see the distributions of capital gain and capital loss

# %%
plt.figure(figsize=(13,13))
sns.histplot(df_copy['capital-gain'],kde=True)
# Out:
# <AxesSubplot:xlabel='capital-gain', ylabel='Count'>

# %%
df_copy['capital-gain'].value_counts()
# Out:
# 0        26702
# 15024      329
# 7688       263
# 7298       233
# 99999      143
#          ...
# 1455         1
# 4931         1
# 22040        1
# 401          1
# 1086         1
# Name: capital-gain, Length: 118, dtype: int64

# %%
plt.figure(figsize=(13,13))
sns.histplot(df_copy['capital-loss'],kde=True)
# Out:
# <AxesSubplot:xlabel='capital-loss', ylabel='Count'>

# %%
df_copy['capital-loss'].value_counts()
# Out:
# 0       27772
# 1902      189
# 1977      158
# 1887      153
# 1848       49
#         ...
# 1816        1
# 3683        1
# 2282        1
# 1539        1
# 1411        1
# Name: capital-loss, Length: 90, dtype: int64

# %% [markdown]
# ### Capital Gain and Capital Loss are both right skewed distributions

# %% [markdown]
# ## Cleaning is now completed. Let's take a copy of this cleaned data to another dataframe

# %%
df_cleaned=df_copy.copy()

# %%
df_cleaned
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29165 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             29165 non-null  int64
#  1   workclass       29165 non-null  object
#  2   fnlwgt          29165 non-null  int64
#  3   education       29165 non-null  object
#  4   education-num   29165 non-null  int64
#  5   marital-status  29165 non-null  object
#  6   occupation      29165 non-null  object
#  7   relationship    29165 non-null  object
#  8   race            29165 non-null  object
#  9   sex             29165 non-null  object
#  10  capital-gain    29165 non-null  int64
#  11  capital-loss    29165 non-null  int64
#  12  hours-per-week  29165 non-null  int64
#  13  native-country  29165 non-null  object
#  14  income          29165 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.6+ MB

# %% [markdown]
# # Part 3: Data Visualization

# %% [markdown]
# ## Finding the trends of income in the United States with respect to workclass

# %%
df_workclass_salary=df_cleaned[df_cleaned['native-country']=='United-States'].groupby(['workclass','income']).count().reset_index()

# %%
df_workclass_salary
# Out:
#            workclass income    age  fnlwgt  education  education-num  \
# 0        Federal-gov  <=50K    524     524        524            524
# 1        Federal-gov   >50K    323     323        323            323
# 2          Local-gov  <=50K   1351    1351       1351           1351
# 3          Local-gov   >50K    563     563        563            563
# 4            Private  <=50K  15131   15131      15131          15131
# 5            Private   >50K   4415    4415       4415           4415
# 6       Self-emp-inc  <=50K    424     424        424            424
# 7       Self-emp-inc   >50K    546     546        546            546
# 8   Self-emp-not-inc  <=50K   1626    1626       1626           1626
# 9   Self-emp-not-inc   >50K    643     643        643            643
# 10         State-gov  <=50K    856     856        856            856
# 11         State-gov   >50K    316     316        316            316
# 12       Without-pay  <=50K     13      13         13             13
#
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=df_workclass_salary,x='workclass',y='age',hue='income')
plt.ylabel('Count')
plt.title('Salary comparison for every work classes in the United Staes',fontsize=20)
plt.show()

# %% [markdown]
# ### From the above diagram, we understood that the maximum number of employees, who earn more than 50k annually, are coming from private sector.

# %% [markdown]
# ## Comparing Occupation with Sex

# %%
genders=['Male','Female']

for gen in genders:
    d=dict(df_cleaned[df_cleaned['sex']==gen]['occupation'].value_counts())
    ex=np.zeros(len(d))
    ls=list(d.values())
    ind=ls.index(max(d.values()))
    ex[ind]=0.1
    plt.figure(figsize=(9,9))
    plt.pie(x=d.values(),labels=d.keys(),textprops={'fontsize':13},explode=ex,autopct='%1.1f%%')
    plt.title(f'{gen} Vs occupation',fontsize=20)
    plt.tight_layout()

# %% [markdown]
# ### The most common occupations among males and females, are Craft-repair and Adm-cleirical respectively

# %% [markdown]
# ## Finding relationship between age and working hours

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(data=df_cleaned,x='age',y='hours-per-week',hue='sex')
plt.legend(loc='best')
plt.title('Relationship between age and hours-per-week across two different genders',fontsize=20)
plt.show()

# %% [markdown]
# ### We could not find any specific relationship between age and hours-per-week. However, most of the data points lie between 10 to 65 years of age

# %% [markdown]
# ## Checking the count of different races across all the countries

# %%
df_cleaned['race'].value_counts()
# Out:
# White                 25201
# Black                  2627
# Asian-Pac-Islander      825
# Amer-Indian-Eskimo      284
# Other                   228
# Name: race, dtype: int64

# %%
plt.figure(figsize=(16,7))
sns.countplot(data=df_cleaned,x='race')
# Out:
# <AxesSubplot:xlabel='race', ylabel='count'>

# %% [markdown]
# ## Trying to find out the correlation between race and marital-status

# %%
df_race_mstatus_fnlwgt=df_cleaned[['race','marital-status','fnlwgt']]

# %%
df_heatmap=df_race_mstatus_fnlwgt.pivot_table(index='race',values='fnlwgt',columns='marital-status',aggfunc=np.sum)

# %%
df_heatmap
# Out:
# marital-status         Divorced  Married-AF-spouse  Married-civ-spouse  \
# race
# Amer-Indian-Eskimo    6707496.0                NaN        1.391007e+07
# Asian-Pac-Islander    8527205.0                NaN        6.569217e+07
# Black                80782908.0           213844.0        1.516801e+08
# Other                 3832620.0                NaN        1.804162e+07
# White               623820098.0          2715068.0        2.167403e+09
#
# marital-status      Married-spouse-absent  Never-married    Separated  \
# race
# Amer-Indian-Eskimo               970703.0   1.119498e+07    1409242.0
# Asian-Pac-Islander              4717741.0   4.656157e+07    2773344.0
# Black                          10676368.0   2.307168e+08   48364193.0
# Other                           2991151.0   1.520797e+07    2594566.0
# White                          46584190.0   1.417585e+09  120300457.0
#
# marital-status          Widowed
# race
# Amer-Indian-Eskimo     880342.0
# ...

# %%
plt.figure(figsize=(13,8))
sns.heatmap(df_heatmap,annot=True)
plt.title('Distribution of Races and their marital status',fontsize=20)
plt.show()
plt.tight_layout()

# %% [markdown]
# ### From the heatmap, we understood that 'Married-civ-spouse' is the most common marital status among white race, whereas for the black race, 'Never-married' status is the most common one

# %% [markdown]
# ## Trying to check correlation between all the variables by a pairplot

# %%
sns.pairplot(data=df_cleaned,hue='sex')

# %% [markdown]
# ## For the top 7 countries (in terms of data availability), let's find out the frequency across all the academic and professional degrees

# %%
top_7_countries=list(dict(df_cleaned['native-country'].value_counts()[:7]).keys())

# %%
top_7_countries
# Out:
# ['United-States',
#  'Mexico',
#  'Philippines',
#  'Germany',
#  'Puerto-Rico',
#  'Canada',
#  'India']

# %%
for cnt in top_7_countries:
    plt.figure(figsize=(18,5))
    sns.countplot(data=df_cleaned[df_cleaned['native-country']==cnt],x='education')
    plt.title(f'Academic distribution of {cnt}')
    plt.show()
    plt.tight_layout()

# %% [markdown]
# ### We discovered some intriguing information from the diagram above. In the first six nations, there are much fewer students pursuing master's degrees. Nonetheless, in India, there are more students with master's degrees than with other types of degrees combined
